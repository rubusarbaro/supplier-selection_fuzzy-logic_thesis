# %%
# !git clone https://github.com/rubusarbaro/supplier-selection_fuzzy-logic_thesis.git
# Out:
# Cloning into 'supplier-selection_fuzzy-logic_thesis'...
# remote: Enumerating objects: 566, done.
# remote: Counting objects: 100% (184/184), done.
# remote: Compressing objects: 100% (132/132), done.
# remote: Total 566 (delta 94), reused 135 (delta 50), pack-reused 382 (from 1)
# Receiving objects: 100% (566/566), 65.60 MiB | 23.32 MiB/s, done.
# Resolving deltas: 100% (311/311), done.

# %%
# !pip install scikit-fuzzy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.8/920.8 kB 13.9 MB/s eta 0:00:00
# ...

# %%
import fuzzy_supplier_evaluator as fse
import pandas as pd
import simulation

# %%
df = pd.read_excel("supplier-selection_fuzzy-logic_thesis/Results/Massive/Implementation_results-03112025062950.xlsx")
df = df.drop(["Unnamed: 0","Unnamed: 0.1"], axis=1)

# %%
env = simulation.Environment()
env.import_training_df(df)
env.item_master["Supplier ID"] = env.item_master["Supplier ID"].apply(str)
env.item_master["Quotation date"] = pd.to_datetime(env.item_master["Quotation date"]).dt.date

# %%
abc = simulation.Supplier()

# %%
fuzzy_evaluation = pd.DataFrame(data=None, columns=["Iteration", "Supplier ID", "New supplier", "Rule 1", "Rule 2", "Rule 3", "Rule 4", "Rule 5", "Rule 6", "Rule 7", "Rule 8", "Rule 9", "Rule 10", "Rule 11", "Score", "Low", "Regular", "High", "Classification"])    # Create a dataframe to store the results of each fuzzy evaluation.
